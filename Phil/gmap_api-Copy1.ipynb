# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
# Import API key
from config import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
df=pd.read_csv("311dataphilly.csv")
df.head()
# Out:
#    REQUEST_ID           CREATED_ON                REQUEST_TYPE REQUEST_ORIGIN  \
# 0    203364.0  2017-12-15T14:53:00  Street Obstruction/Closure    Call Center
# 1    200800.0  2017-11-29T09:54:00                    Graffiti  Control Panel
# 2    201310.0  2017-12-01T13:23:00                      Litter    Call Center
# 3    200171.0  2017-11-22T14:54:00            Water Main Break    Call Center
# 4    193043.0  2017-10-12T12:46:00                  Guide Rail    Call Center
#
#    STATUS                            DEPARTMENT       NEIGHBORHOOD  \
# 0       1                        DOMI - Permits  Central Northside
# 1       1                    Police - Zones 1-6   South Side Flats
# 2       1              DPW - Street Maintenance          Troy Hill
# 3       0  Pittsburgh Water and Sewer Authority         Banksville
# 4       1           DPW - Construction Division         East Hills
#
#    COUNCIL_DISTRICT  WARD         TRACT  PUBLIC_WORKS_DIVISION  PLI_DIVISION  \
# 0               1.0  22.0  4.200322e+10                    1.0          22.0
# 1               3.0  16.0  4.200316e+10                    3.0          16.0
# 2               1.0  24.0  4.200324e+10                    1.0          24.0
# 3               2.0  20.0  4.200320e+10                    5.0          20.0
# 4               9.0  13.0  4.200313e+10                    2.0          13.0
#
#    POLICE_ZONE FIRE_ZONE          X          Y GEO_ACCURACY
# 0          1.0     7-Jan -80.016716  40.454144        EXACT
# 1          3.0    24-Apr -79.969952  40.429243  APPROXIMATE
# 2          1.0     2-Jan -79.985859  40.459716        EXACT
# 3          6.0     9-Apr -80.034210  40.406969        EXACT
# 4          5.0    19-Mar -79.876582  40.451226        EXACT

# %%
#configure gmaps with API key
gmaps.configure(api_key=g_key)

# %%
#Store lat and long into Locations
df=df.dropna()
#locations=df[['Y','X']].astype(float)

# %%
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?latlng=40.454144,-80.016716&location_type=APPROXIMATE&result_type=postal_code&key=AIzaSyA-ID1L5POajfL01AYW2ZHTmER2A5mJT4M')

geo_data=requests.get(target_url).json()
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "plus_code": {
#         "compound_code": "FX3M+M8 Pittsburgh, PA, USA",
#         "global_code": "86GXFX3M+M8"
#     },
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "15233",
#                     "short_name": "15233",
#                     "types": [
#                         "postal_code"
#                     ]
#                 },
#                 {
#                     "long_name": "Pittsburgh",
#                     "short_name": "Pittsburgh",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Allegheny County",
#                     "short_name": "Allegheny County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Pennsylvania",
#                     "short_name": "PA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Pittsburgh, PA 15233, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 40.478524,
#                         "lng": -80.01341289999999
#                     },
#                     "southwest": {
#                         "lat": 40.4461991,
#                         "lng": -80.051178
#                     }
#                 },
#                 "location": {
#                     "lat": 40.4543466,
#                     "lng": -80.0283415
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.478524,
#                         "lng": -80.01341289999999
#                     },
#                     "southwest": {
#                         "lat": 40.4461991,
#                         "lng": -80.051178
#                     }
#                 }
#             },
#             "place_id": "ChIJwTNqYhX0NIgRE3o-fZFM5tQ",
#             "postcode_localities": [
#                 "Kilbuck Township",
#                 "Pittsburgh"
#             ],
#             "types": [
#                 "postal_code"
#             ]
#         }
#     ],
#     "status": "OK"
# }

# %%
#df_narrow=df[(df['Max Temp']<70) & (df['Wind']<10) & (df['Cloudiness']==0)]
#df_narrow

# %%
#hotel_df=df_narrow[['City','Latitude','Longtitude','Humidity']]
#hotel_df['Location']=list(zip(hotel_df.Latitude,hotel_df.Longtitude))
#hotel_df['Location'].str.replace(r"\(.*\)","")
#Location=f"{Latitude},{Longtitude}"
#hotel_df

# %%
df.loc[0:,'ZIP'] = ""
df.loc[0:,'location']=df['Y'].astype(str)+','+df['X'].astype(str)

#Y=df['Y']
#X=df['X']
#hotel_df['address'] = ""
#types_df['price_level'] = ""
#types_df['rating'] = ""
df
# Out:
#         REQUEST_ID           CREATED_ON                REQUEST_TYPE  \
# 0         203364.0  2017-12-15T14:53:00  Street Obstruction/Closure
# 1         200800.0  2017-11-29T09:54:00                    Graffiti
# 2         201310.0  2017-12-01T13:23:00                      Litter
# 3         200171.0  2017-11-22T14:54:00            Water Main Break
# 4         193043.0  2017-10-12T12:46:00                  Guide Rail
# ...            ...                  ...                         ...
# 392976    410539.0  2020-01-21T20:49:00   Building Without a Permit
# 392977    410540.0  2020-01-21T21:49:00               Early Set Out
# 392978    410541.0  2020-01-21T21:58:00                   Recycling
# 392979    410542.0  2020-01-21T22:28:00             Missed Blue Bag
# 392980    410543.0  2020-01-21T22:29:00      Leaves/Street Cleaning
#
#         REQUEST_ORIGIN  STATUS                            DEPARTMENT  \
# 0          Call Center       1                        DOMI - Permits
# 1        Control Panel       1                    Police - Zones 1-6
# 2          Call Center       1              DPW - Street Maintenance
# 3          Call Center       0  Pittsburgh Water and Sewer Authority
# 4          Call Center       1           DPW - Construction Division
# ...                ...     ...                                   ...
# 392976         Website       0     Permits, Licenses and Inspections
# 392977         Website       0                          DPW - Refuse
# 392978         Website       0                          DPW - Refuse
# 392979  Report2Gov iOS       0                          DPW - Refuse
# 392980  Report2Gov iOS       0              DPW - Street Maintenance
#
#              NEIGHBORHOOD  COUNCIL_DISTRICT  WARD         TRACT  \
# 0       Central Northside               1.0  22.0  4.200322e+10
# 1        South Side Flats               3.0  16.0  4.200316e+10
# 2               Troy Hill               1.0  24.0  4.200324e+10
# 3              Banksville               2.0  20.0  4.200320e+10
# 4              East Hills               9.0  13.0  4.200313e+10
# ...                   ...               ...   ...           ...
# 392976     Allegheny West               1.0  22.0  4.200356e+10
# 392977          Shadyside               8.0   7.0  4.200307e+10
# 392978          Shadyside               8.0   7.0  4.200307e+10
# 392979        Morningside               7.0  10.0  4.200310e+10
# 392980           Garfield               9.0  11.0  4.200311e+10
#
#         PUBLIC_WORKS_DIVISION  PLI_DIVISION  POLICE_ZONE FIRE_ZONE          X  \
# 0                         1.0          22.0          1.0     7-Jan -80.016716
# 1                         3.0          16.0          3.0    24-Apr -79.969952
# 2                         1.0          24.0          1.0     2-Jan -79.985859
# 3                         5.0          20.0          6.0     9-Apr -80.034210
# 4                         2.0          13.0          5.0    19-Mar -79.876582
# ...                       ...           ...          ...       ...        ...
# 392976                    1.0          22.0          1.0     7-Jan -80.014456
# 392977                    2.0           7.0          4.0    11-Mar -79.930895
# 392978                    2.0           7.0          4.0    11-Mar -79.930668
# 392979                    2.0          10.0          5.0     7-Mar -79.930155
# 392980                    2.0          11.0          5.0     4-Mar -79.931702
#
#                 Y GEO_ACCURACY ZIP                         location
# 0       40.454144        EXACT                40.4541445,-80.016716
# 1       40.429243  APPROXIMATE             40.42924284,-79.96995168
# 2       40.459716        EXACT        40.4597155,-79.98585859999999
# 3       40.406969        EXACT        40.4069693,-80.03420990000001
# 4       40.451226        EXACT               40.45122643,-79.876582
# ...           ...          ...  ..                              ...
# 392976  40.451034  APPROXIMATE             40.45103412,-80.01445607
# 392977  40.453793  APPROXIMATE             40.45379271,-79.93089484
# 392978  40.454146  APPROXIMATE      40.454145700000005,-79.93066772
# 392979  40.475395  APPROXIMATE             40.47539522,-79.93015454
# 392980  40.470051        EXACT                 40.470051,-79.931702
#
# [362880 rows x 19 columns]

# %%
df_n=df[:100]
#df.loc[0:,'ZIP'] = ""

base_url = "https://maps.googleapis.com/maps/api/geocode/json"
params = {
    #"sensor":true/false
    "key":"AIzaSyA-ID1L5POajfL01AYW2ZHTmER2A5mJT4M"
    "location_type":"postal_code"
}
# use iterrows to iterate through pandas dataframe
for index,row in df_n.iterrows():

    # get coordinates type from df!!!!
    zip_loc = row['location']
    #lat=row['Y']
    #lon=row['X']
    #zip_loc=f'{lat},{lon}'
    # add location to params dict
    #params['latlng'] =f"{lat},{lon}"
    params['latlng']=zip_loc
    # assemble url and make API request
    #print(f"Retrieving Results for Index {index}: { zip_loc}.")
    response = requests.get(base_url, params=params).json()
    # extract results
    results = response['results']
    #print({results})
    try:
        #print(f"Closest hotel in {city_name}  is {results[0]['name']}.")
        
        df_n.loc[index,'ZIP'] = results[0]["address_components"]
        #types_df.loc[index, 'address'] = results[0]['vicinity']
        #types_df.loc[index, 'price_level'] = results[0]['price_level']
        #types_df.loc[index, 'rating'] = results[0]['rating']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
#   File "<ipython-input-71-206ff37e0287>", line 8
#     "location_type":"postal_code"
#                    ^
# SyntaxError: invalid syntax

# %%
response
# Out:
# {'error_message': 'Missing the placeid or reference parameter.',
#  'html_attributions': [],
#  'status': 'INVALID_REQUEST'}

# %%
print(json.dumps(results, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "address_components": [
#             {
#                 "long_name": "1636",
#                 "short_name": "1636",
#                 "types": [
#                     "street_number"
#                 ]
#             },
#             {
#                 "long_name": "Bedford Avenue",
#                 "short_name": "Bedford Ave",
#                 "types": [
#                     "route"
#                 ]
#             },
#             {
#                 "long_name": "Crawford-Roberts",
#                 "short_name": "Crawford-Roberts",
#                 "types": [
#                     "neighborhood",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pittsburgh",
#                 "short_name": "Pittsburgh",
#                 "types": [
#                     "locality",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Allegheny County",
#                 "short_name": "Allegheny County",
#                 "types": [
#                     "administrative_area_level_2",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pennsylvania",
#                 "short_name": "PA",
#                 "types": [
#                     "administrative_area_level_1",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "United States",
#                 "short_name": "US",
#                 "types": [
#                     "country",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "15219",
#                 "short_name": "15219",
#                 "types": [
#                     "postal_code"
#                 ]
#             },
#             {
#                 "long_name": "3604",
#                 "short_name": "3604",
#                 "types": [
#                     "postal_code_suffix"
#                 ]
#             }
#         ],
#         "formatted_address": "1636 Bedford Ave, Pittsburgh, PA 15219, USA",
#         "geometry": {
#             "location": {
#                 "lat": 40.4447243,
#                 "lng": -79.98627259999999
#             },
#             "location_type": "ROOFTOP",
#             "viewport": {
#                 "northeast": {
#                     "lat": 40.4460732802915,
#                     "lng": -79.98492361970848
#                 },
#                 "southwest": {
#                     "lat": 40.4433753197085,
#                     "lng": -79.9876215802915
#                 }
#             }
#         },
#         "place_id": "ChIJ0S7S2N_zNIgRRNYZeoV8sYM",
#         "plus_code": {
#             "compound_code": "C2V7+VF Pittsburgh, Pennsylvania, United States",
#             "global_code": "87G2C2V7+VF"
#         },
#         "types": [
#             "street_address"
#         ]
#     },
#     {
#         "address_components": [
#             {
#                 "long_name": "Bedford Ave at Manilla St",
#                 "short_name": "Bedford Ave at Manilla St",
#                 "types": [
#                     "establishment",
#                     "point_of_interest",
#                     "transit_station"
#                 ]
#             },
#             {
#                 "long_name": "Crawford-Roberts",
#                 "short_name": "Crawford-Roberts",
#                 "types": [
#                     "neighborhood",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pittsburgh",
#                 "short_name": "Pittsburgh",
#                 "types": [
#                     "locality",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Allegheny County",
#                 "short_name": "Allegheny County",
#                 "types": [
#                     "administrative_area_level_2",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pennsylvania",
#                 "short_name": "PA",
#                 "types": [
#                     "administrative_area_level_1",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "United States",
#                 "short_name": "US",
#                 "types": [
#                     "country",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "15219",
#                 "short_name": "15219",
#                 "types": [
#                     "postal_code"
#                 ]
#             }
#         ],
#         "formatted_address": "Bedford Ave at Manilla St, Pittsburgh, PA 15219, USA",
#         "geometry": {
#             "location": {
#                 "lat": 40.444936,
#                 "lng": -79.986233
#             },
#             "location_type": "GEOMETRIC_CENTER",
#             "viewport": {
#                 "northeast": {
#                     "lat": 40.44628498029149,
#                     "lng": -79.9848840197085
#                 },
#                 "southwest": {
#                     "lat": 40.4435870197085,
#                     "lng": -79.98758198029151
#                 }
#             }
#         },
#         "place_id": "ChIJ0UM12N_zNIgR6SiUQQ0CIc0",
#         "plus_code": {
#             "compound_code": "C2V7+XG Pittsburgh, Pennsylvania, United States",
#             "global_code": "87G2C2V7+XG"
#         },
#         "types": [
#             "establishment",
#             "point_of_interest",
#             "transit_station"
#         ]
#     },
#     {
#         "address_components": [
#             {
#                 "long_name": "472",
#                 "short_name": "472",
#                 "types": [
#                     "street_number"
#                 ]
#             },
#             {
#                 "long_name": "Manilla Street",
#                 "short_name": "Manilla St",
#                 "types": [
#                     "route"
#                 ]
#             },
#             {
#                 "long_name": "Crawford-Roberts",
#                 "short_name": "Crawford-Roberts",
#                 "types": [
#                     "neighborhood",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pittsburgh",
#                 "short_name": "Pittsburgh",
#                 "types": [
#                     "locality",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Allegheny County",
#                 "short_name": "Allegheny County",
#                 "types": [
#                     "administrative_area_level_2",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pennsylvania",
#                 "short_name": "PA",
#                 "types": [
#                     "administrative_area_level_1",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "United States",
#                 "short_name": "US",
#                 "types": [
#                     "country",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "15219",
#                 "short_name": "15219",
#                 "types": [
#                     "postal_code"
#                 ]
#             }
#         ],
#         "formatted_address": "472 Manilla St, Pittsburgh, PA 15219, USA",
#         "geometry": {
#             "location": {
#                 "lat": 40.444747,
#                 "lng": -79.98618139999999
#             },
#             "location_type": "RANGE_INTERPOLATED",
#             "viewport": {
#                 "northeast": {
#                     "lat": 40.4460959802915,
#                     "lng": -79.98483241970848
#                 },
#                 "southwest": {
#                     "lat": 40.4433980197085,
#                     "lng": -79.9875303802915
#                 }
#             }
#         },
#         "place_id": "Eik0NzIgTWFuaWxsYSBTdCwgUGl0dHNidXJnaCwgUEEgMTUyMTksIFVTQSIbEhkKFAoSCdUMtN7f8zSIERpCe2nycR9UENgD",
#         "types": [
#             "street_address"
#         ]
#     },
#     {
#         "address_components": [
#             {
#                 "long_name": "657-53",
#                 "short_name": "657-53",
#                 "types": [
#                     "street_number"
#                 ]
#             },
#             {
#                 "long_name": "Manilla Street",
#                 "short_name": "Manilla St",
#                 "types": [
#                     "route"
#                 ]
#             },
#             {
#                 "long_name": "Crawford-Roberts",
#                 "short_name": "Crawford-Roberts",
#                 "types": [
#                     "neighborhood",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pittsburgh",
#                 "short_name": "Pittsburgh",
#                 "types": [
#                     "locality",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Allegheny County",
#                 "short_name": "Allegheny County",
#                 "types": [
#                     "administrative_area_level_2",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pennsylvania",
#                 "short_name": "PA",
#                 "types": [
#                     "administrative_area_level_1",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "United States",
#                 "short_name": "US",
#                 "types": [
#                     "country",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "15219",
#                 "short_name": "15219",
#                 "types": [
#                     "postal_code"
#                 ]
#             }
#         ],
#         "formatted_address": "657-53 Manilla St, Pittsburgh, PA 15219, USA",
#         "geometry": {
#             "bounds": {
#                 "northeast": {
#                     "lat": 40.4448763,
#                     "lng": -79.98598609999999
#                 },
#                 "southwest": {
#                     "lat": 40.4444792,
#                     "lng": -79.98627570000001
#                 }
#             },
#             "location": {
#                 "lat": 40.4446778,
#                 "lng": -79.98613089999999
#             },
#             "location_type": "GEOMETRIC_CENTER",
#             "viewport": {
#                 "northeast": {
#                     "lat": 40.44602673029149,
#                     "lng": -79.9847819197085
#                 },
#                 "southwest": {
#                     "lat": 40.44332876970849,
#                     "lng": -79.98747988029152
#                 }
#             }
#         },
#         "place_id": "ChIJ1Qy03t_zNIgRGkJ7afJxH1Q",
#         "types": [
#             "route"
#         ]
#     },
#     {
#         "address_components": [
#             {
#                 "long_name": "Crawford-Roberts",
#                 "short_name": "Crawford-Roberts",
#                 "types": [
#                     "neighborhood",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pittsburgh",
#                 "short_name": "Pittsburgh",
#                 "types": [
#                     "locality",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Allegheny County",
#                 "short_name": "Allegheny County",
#                 "types": [
#                     "administrative_area_level_2",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pennsylvania",
#                 "short_name": "PA",
#                 "types": [
#                     "administrative_area_level_1",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "United States",
#                 "short_name": "US",
#                 "types": [
#                     "country",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "15219",
#                 "short_name": "15219",
#                 "types": [
#                     "postal_code"
#                 ]
#             }
#         ],
#         "formatted_address": "Crawford-Roberts, Pittsburgh, PA 15219, USA",
#         "geometry": {
#             "bounds": {
#                 "northeast": {
#                     "lat": 40.4484656,
#                     "lng": -79.9751902
#                 },
#                 "southwest": {
#                     "lat": 40.4382306,
#                     "lng": -79.992764
#                 }
#             },
#             "location": {
#                 "lat": 40.441507,
#                 "lng": -79.9822126
#             },
#             "location_type": "APPROXIMATE",
#             "viewport": {
#                 "northeast": {
#                     "lat": 40.4484656,
#                     "lng": -79.9751902
#                 },
#                 "southwest": {
#                     "lat": 40.4382306,
#                     "lng": -79.992764
#                 }
#             }
#         },
#         "place_id": "ChIJv68BdN_zNIgR5mUEy5Tj9iI",
#         "types": [
#             "neighborhood",
#             "political"
#         ]
#     },
#     {
#         "address_components": [
#             {
#                 "long_name": "15219",
#                 "short_name": "15219",
#                 "types": [
#                     "postal_code"
#                 ]
#             },
#             {
#                 "long_name": "Pittsburgh",
#                 "short_name": "Pittsburgh",
#                 "types": [
#                     "locality",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Allegheny County",
#                 "short_name": "Allegheny County",
#                 "types": [
#                     "administrative_area_level_2",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pennsylvania",
#                 "short_name": "PA",
#                 "types": [
#                     "administrative_area_level_1",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "United States",
#                 "short_name": "US",
#                 "types": [
#                     "country",
#                     "political"
#                 ]
#             }
#         ],
#         "formatted_address": "Pittsburgh, PA 15219, USA",
#         "geometry": {
#             "bounds": {
#                 "northeast": {
#                     "lat": 40.472077,
#                     "lng": -79.840588
#                 },
#                 "southwest": {
#                     "lat": 40.4292079,
#                     "lng": -80.04131679999999
#                 }
#             },
#             "location": {
#                 "lat": 40.440368,
#                 "lng": -79.9836108
#             },
#             "location_type": "APPROXIMATE",
#             "viewport": {
#                 "northeast": {
#                     "lat": 40.472077,
#                     "lng": -79.840588
#                 },
#                 "southwest": {
#                     "lat": 40.4292079,
#                     "lng": -80.04131679999999
#                 }
#             }
#         },
#         "place_id": "ChIJBRRSZV_xNIgRMDq4kUKLVqM",
#         "types": [
#             "postal_code"
#         ]
#     },
#     {
#         "address_components": [
#             {
#                 "long_name": "Pittsburgh",
#                 "short_name": "Pittsburgh",
#                 "types": [
#                     "locality",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Allegheny County",
#                 "short_name": "Allegheny County",
#                 "types": [
#                     "administrative_area_level_2",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pennsylvania",
#                 "short_name": "PA",
#                 "types": [
#                     "administrative_area_level_1",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "United States",
#                 "short_name": "US",
#                 "types": [
#                     "country",
#                     "political"
#                 ]
#             }
#         ],
#         "formatted_address": "Pittsburgh, PA, USA",
#         "geometry": {
#             "bounds": {
#                 "northeast": {
#                     "lat": 40.501368,
#                     "lng": -79.8657231
#                 },
#                 "southwest": {
#                     "lat": 40.3613689,
#                     "lng": -80.0952779
#                 }
#             },
#             "location": {
#                 "lat": 40.44062479999999,
#                 "lng": -79.9958864
#             },
#             "location_type": "APPROXIMATE",
#             "viewport": {
#                 "northeast": {
#                     "lat": 40.501368,
#                     "lng": -79.8657231
#                 },
#                 "southwest": {
#                     "lat": 40.3613689,
#                     "lng": -80.0952779
#                 }
#             }
#         },
#         "place_id": "ChIJA4UGSG_xNIgRNBuiWqEV-Y0",
#         "types": [
#             "locality",
#             "political"
#         ]
#     },
#     {
#         "address_components": [
#             {
#                 "long_name": "Allegheny County",
#                 "short_name": "Allegheny County",
#                 "types": [
#                     "administrative_area_level_2",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Pennsylvania",
#                 "short_name": "PA",
#                 "types": [
#                     "administrative_area_level_1",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "United States",
#                 "short_name": "US",
#                 "types": [
#                     "country",
#                     "political"
#                 ]
#             }
#         ],
#         "formatted_address": "Allegheny County, PA, USA",
#         "geometry": {
#             "bounds": {
#                 "northeast": {
#                     "lat": 40.67453,
#                     "lng": -79.688761
#                 },
#                 "southwest": {
#                     "lat": 40.1943428,
#                     "lng": -80.36087289999999
#                 }
#             },
#             "location": {
#                 "lat": 40.4450813,
#                 "lng": -80.0087746
#             },
#             "location_type": "APPROXIMATE",
#             "viewport": {
#                 "northeast": {
#                     "lat": 40.67453,
#                     "lng": -79.688761
#                 },
#                 "southwest": {
#                     "lat": 40.1943428,
#                     "lng": -80.36087289999999
#                 }
#             }
#         },
#         "place_id": "ChIJu-PIH-y5NIgRVFV1McCaCyw",
#         "types": [
#             "administrative_area_level_2",
#             "political"
#         ]
#     },
#     {
#         "address_components": [
#             {
#                 "long_name": "Pennsylvania",
#                 "short_name": "PA",
#                 "types": [
#                     "administrative_area_level_1",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "United States",
#                 "short_name": "US",
#                 "types": [
#                     "country",
#                     "political"
#                 ]
#             }
#         ],
#         "formatted_address": "Pennsylvania, USA",
#         "geometry": {
#             "bounds": {
#                 "northeast": {
#                     "lat": 42.5141658,
#                     "lng": -74.6895018
#                 },
#                 "southwest": {
#                     "lat": 39.7197989,
#                     "lng": -80.51989499999999
#                 }
#             },
#             "location": {
#                 "lat": 41.2033216,
#                 "lng": -77.1945247
#             },
#             "location_type": "APPROXIMATE",
#             "viewport": {
#                 "northeast": {
#                     "lat": 42.5141658,
#                     "lng": -74.6895018
#                 },
#                 "southwest": {
#                     "lat": 39.7197989,
#                     "lng": -80.51989499999999
#                 }
#             }
#         },
#         "place_id": "ChIJieUyHiaALYgRPbQiUEchRsI",
#         "types": [
#             "administrative_area_level_1",
#             "political"
#         ]
#     },
#     {
#         "address_components": [
#             {
#                 "long_name": "United States",
#                 "short_name": "US",
#                 "types": [
#                     "country",
#                     "political"
#                 ]
#             }
#         ],
#         "formatted_address": "United States",
#         "geometry": {
#             "bounds": {
#                 "northeast": {
#                     "lat": 71.5388001,
#                     "lng": -66.885417
#                 },
#                 "southwest": {
#                     "lat": 18.7763,
#                     "lng": 170.5957
#                 }
#             },
#             "location": {
#                 "lat": 37.09024,
#                 "lng": -95.712891
#             },
#             "location_type": "APPROXIMATE",
#             "viewport": {
#                 "northeast": {
#                     "lat": 71.5388001,
#                     "lng": -66.885417
#                 },
#                 "southwest": {
#                     "lat": 18.7763,
#                     "lng": 170.5957
#                 }
#             }
#         },
#         "place_id": "ChIJCzYy5IS16lQRQrfeQ5K5Oxw",
#         "types": [
#             "country",
#             "political"
#         ]
#     }
# ]
