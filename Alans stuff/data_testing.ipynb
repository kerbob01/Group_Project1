# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import pprint
from census import Census
from us import states
import csv
print(os.getcwd())
#os.chdir(C:\Users\alana\OneDrive\Desktop\GitHub\Group_Project1)
census = pd.read_csv("311dataphilly_test.csv", encoding="utf-8")
# Out:
# C:\Users\alana\OneDrive\Desktop\GitHub\Group_Project1

# %%
#Reads CSV file
census = pd.read_csv("311dataphilly_test.csv", encoding="utf-8")
census.head()
# Out:
#    REQUEST_ID           CREATED_ON                REQUEST_TYPE REQUEST_ORIGIN  \
# 0      203364  2017-12-15T14:53:00  Street Obstruction/Closure    Call Center
# 1      200800  2017-11-29T09:54:00                    Graffiti  Control Panel
# 2      201310  2017-12-01T13:23:00                      Litter    Call Center
# 3      200171  2017-11-22T14:54:00            Water Main Break    Call Center
# 4      193043  2017-10-12T12:46:00                  Guide Rail    Call Center
#
#    STATUS                            DEPARTMENT       NEIGHBORHOOD  \
# 0       1                        DOMI - Permits  Central Northside
# 1       1                    Police - Zones 1-6   South Side Flats
# 2       1              DPW - Street Maintenance          Troy Hill
# 3       0  Pittsburgh Water and Sewer Authority         Banksville
# 4       1           DPW - Construction Division         East Hills
#
#    COUNCIL_DISTRICT  WARD        TRACT  PUBLIC_WORKS_DIVISION  PLI_DIVISION  \
# ...

# %%
clean_311 = pd.DataFrame(census, columns =["CREATED_ON", "REQUEST_TYPE", "REQUEST_ORIGIN", "DEPARTMENT",
                                             "NEIGHBORHOOD", "X", "Y", "Zipcode"])

clean_311.head()
# Out:
#             CREATED_ON                REQUEST_TYPE REQUEST_ORIGIN  \
# 0  2017-12-15T14:53:00  Street Obstruction/Closure    Call Center
# 1  2017-11-29T09:54:00                    Graffiti  Control Panel
# 2  2017-12-01T13:23:00                      Litter    Call Center
# 3  2017-11-22T14:54:00            Water Main Break    Call Center
# 4  2017-10-12T12:46:00                  Guide Rail    Call Center
#
#                              DEPARTMENT       NEIGHBORHOOD          X  \
# 0                        DOMI - Permits  Central Northside -80.016716
# 1                    Police - Zones 1-6   South Side Flats -79.969952
# 2              DPW - Street Maintenance          Troy Hill -79.985859
# 3  Pittsburgh Water and Sewer Authority         Banksville -80.034210
# 4           DPW - Construction Division         East Hills -79.876582
#
#            Y  Zipcode
# 0  40.454144    19019
# 1  40.429243    19132
# 2  40.459716    19144
# 3  40.406969    19019
# 4  40.451226    19132

# %%
#print(len(weather_df))
#saves to CSV file
clean_311.to_csv("clean_311.csv", index=False, header=True)
